# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
t = [100, 500, 1000, 2000, 6000]
U235t = [63.67, 66.24, 67.45, 67.56, 67.55]
U235to = [62.37, 65.84, 66.73, 67.19, 67.52]
U235f = [52.37, 56.14, 56.65, 56.8, 56.84]
U235fo = [51.29, 55.48, 55.47, 56.72, 56.81]
U235g = [11.3, 11.1, 10.8, 10.76, 10.71]
U235go = [10.60, 10.88, 10.76, 10.72, 10.73]
U238t = [0.931, 0.874, 0.762, 0.751, 0.757]
U238to = [0.929, 0.863, 0.757, 0.75, 0.759]
U238f = [0.105, 0.11, 0.111, 0.112, 0.112]
U238fo = [0.107, 0.11, 0.115, 0.117, 0.117]
U238g = [0.826, 0.764, 0.651, 0.639, 0.635]
U238go = [0.831, 0.769, 0.661, 0.634, 0.631]

# %%
plt.figure('U235')
plt.plot(t, U235t, 'k--', label = "XSgen Total")
plt.plot(t, U235f, 'k--+', label = "XSgen Fission")
plt.plot(t, U235g, 'k--^', label = r"XSgen $(n, \gamma$)")
plt.plot(t, U235to, 'k-', label = "OpenMC Total")
plt.plot(t, U235fo, 'k-+', label = "OpenMC Fission")
plt.plot(t, U235go, 'k-^', label = r"OpenMC $(n, \gamma$)")
plt.ylim([0, 70])
plt.xlabel('Time [Days]')
plt.ylabel('U235 Cross Section [b]')
plt.legend()
plt.savefig('U235xs.eps', format="eps")
plt.show()

# %%
plt.figure('U238')
plt.plot(t, U238t, 'k--', label = "XSgen Total")
plt.plot(t, U238f, 'k--+', label = "XSgen Fission")
plt.plot(t, U238g, 'k--^', label = r"XSgen $(n, \gamma$)")
plt.plot(t, U238to, 'k-', label = "OpenMC Total")
plt.plot(t, U238fo, 'k-+', label = "OpenMC Fission")
plt.plot(t, U238go, 'k-^', label = r"OpenMC $(n, \gamma$)")
plt.ylim(0, 1.0)
plt.xlabel('Time [Days]')
plt.ylabel('U238 Cross Section [b]')
plt.legend()
plt.savefig('U238xs.eps', format="eps")
plt.show()
